# %%
# %run main.py
# Out:
# 2025-03-01 07:52:22,161 - INFO - []
# ...

# %%
# %who
# Out:
# NoCredentialsError	 Settings	 Template	 argparse	 boto3	 combination_of_some_days_list	 cr	 datetime	 dict_zaw
# exp	 find_day_request	 get_dict	 get_list_construction_place	 html_template	 inf	 lg	 logging	 os
# pprint	 rozklad_curs	 save_google_sheet	 save_html	 upload_directory_to_s3

# %%
pprint(dict_zaw)
# Out:
# {'Zaktualizowano': 'Zaktualizowano na: 01.03.2025 07:53',
#  'brend': 'Produced for "Trans-Serwis"',
#  'cong': '',
#  'gora': {'clean_metrs_1': 0,
#           'clean_metrs_2': np.float64(27.0),
#           'clean_metrs_3': np.float64(36.0),
#           'count_1': 0,
#           'count_2': 4,
#           'count_3': 5,
#           'element1': ['01.03.2025 sobota', 'Dane są niedostępne'],
#           'element2': ['03.03.2025 poniedziałek', 'Dane są niedostępne'],
#           'element3': ['04.03.2025 wtorek', 'Dane są niedostępne'],
#           'element4': ['01.03.2025 sobota', 'Dane są niedostępne'],
#           'element5': ['03.03.2025  poniedziałek',
#                        '<p style="font-weight: bold; margin-bottom: '
#                        '3px">zaplanowano metrów - 27.0</p>',
#                        '<span style="color: rgb(0, 139, 7); font-weight: '
#                        'bold;">08:00 8.0 węzeł 1</span>',
# ...
